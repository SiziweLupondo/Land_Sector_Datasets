# %% [markdown]
# <p style="font-family: Candara; line-height: 2; font-size: 31px; font-weight: bold; letter-spacing: 1px; text-align: center; color: #01796F">SOUTH AFRICA SUSTAINABLE DEVELOPMENT GOALS</p>
#
# <hr style="height: 0.5px; border: 0; background-color: #342D7E">

# %% [markdown]
# <p style="font-family: Candara; font-size: 25px; font-style: normal; font-weight: bold; letter-spacing: 3px; text-align: left; color: #01796F; line-height:1.0">TABLE OF CONTENT</p>
#
# <p style="font-family: Candara; font-size: 15px; font-style: normal; font-weight: bold; letter-spacing: 2px; text-align: left; color:  #342D7E; line-height:1"><a href="#part1" style="color:#01796F">1. INTRODUCTION</a></p>
#
# <p style="font-family: Candara; font-size: 15px; font-style: normal; font-weight: bold; letter-spacing: 2px; text-align: left; color: #01796F; line-height:1"><a href="#part2" style="color:#01796F">2. LIBRARIES</a></p>
#
# <p style="font-family: Candara; font-size: 15px; font-style: normal; font-weight: bold; letter-spacing: 2px; text-align: left; color: #01796F; line-height:1"><a href="#part3" style="color:#01796F">3. IMPORT DATA </a></p>
#
# <p style="font-family: Candara; font-size: 15px; font-style: normal; font-weight: bold; letter-spacing: 2px; text-align: left; color: #01796F; line-height:1"><a href="#part4" style="color:#01796F">4. ADMNINISTRATIVE BOUNDARY</a></p>
#
# <p style="font-family: Candara; font-size: 15px; font-style: normal; font-weight: bold; letter-spacing: 2px; text-align: left; color: #01796F; line-height:1"><a href="#part5" style="color:#01796F">5. BIODIVERSIRTY HOTSPOT</a></p>
#
# <p style="font-family: Candara; font-size: 15px; font-style: normal; font-weight: bold; letter-spacing: 2px; text-align: left; color: #01796F; line-height:1"><a href="#part9" style="color:#01796F">9. CONLCUSION</a></p>
#
# <p style="font-family: Candara; font-size: 15px; font-style: normal; font-weight: bold; letter-spacing: 2px; text-align: left; color: #01796F; line-height:1"><a href="#part10" style="color:#01796F">10. REFERENCES</a></p>

# %% [markdown]
# <a class="anchor" id="part1"></a>
# # <span style="font-family: candara; font-size: 25px; font-style: normal; font-weight: bold; letter-spacing: 3px; text-align: center; color:  #01796F; line-height:1.0">1. Introduction to South Africa's Sustainable Development Goals (SDGs) </span>
#
# <a class="anchor" id="part1"></a>
#
# <hr style="height: 0.5px; border: 0; background-color: #342D7E">

# %% [markdown]
# South Africa, a nation known for its cultural and natural diversity, has embarked on a transformative journey towards a sustainable and equitable future. At the heart of this endeavor are the Sustainable Development Goals (SDGs), a universal call to action to end poverty, protect the planet, and ensure prosperity for all by 2030. These seventeen interlinked goals address a range of complex and interconnected global challenges, from poverty alleviation to climate action, and South Africa has wholeheartedly committed to their achievement.
#
# This research project delves into South Africa's pursuit of the SDGs, offering a comprehensive exploration of the nation's progress, challenges, and strategies in its quest for sustainable development. By examining the specific context of South Africa, including its historical legacies and unique socio-economic dynamics, this research aims to provide a nuanced understanding of how the SDGs are shaping the country's policies, initiatives, and partnerships.
#
# In the following sections, we will delve into the background of the SDGs in South Africa, the key goals and targets, and the role of various stakeholders, including government bodies, civil society, and the private sector. We will also examine the challenges and opportunities that arise on this path, and the implications of South Africa's progress toward the SDGs on local and global scales.
#
# South Africa's commitment to the SDGs reflects not only its desire for a more sustainable and inclusive future but also its recognition of the interconnectedness of global challenges. This research project aims to shed light on the multifaceted efforts underway to address these challenges and contribute to the broader conversation about sustainable development in South Africa and beyond.

# %% [markdown]
# <a class="anchor" id="part2"></a>
# # <span style="font-family: candara; font-size: 25px; font-style: normal; font-weight: bold; letter-spacing: 3px; text-align: center; color:  #01796F; line-height:1.0">2. Import necessary libraries </span>
#
#
# <hr style="height: 0.5px; border: 0; background-color: #342D7E">

# %%
# Import necessary libraries
import geopandas as gpd
import io, requests , fiona

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <a class="anchor" id="part3"></a>
# # <span style="font-family: candara; font-size: 25px; font-style: normal; font-weight: bold; letter-spacing: 3px; text-align: center; color:  #01796F; line-height:1.0">3. Import Data </span>
#
# <hr style="height: 0.5px; border: 0; background-color: #342D7E">

# %%
"""
This code reads a JSON or GeoJSON file from a link and returns a DataFrame 
(assuming you have pandas, geopandas, fiona and requests installed)

"""

def get_df(link):
    """
    Inputs a link to a JSON/GeoJSON file and returns a DataFrame
    """
    try:
        # Try reading the file directly
        return gpd.read_file(link)
    except Exception as e:
        print(f"Error: {e}")
        print("Retrieving the DataFrame from the URL.")

        try:
            # Retrieve data from the URL
            req = requests.get(link).content
            # Read the content as a GeoDataFrame
            return gpd.read_file(io.StringIO(req.decode('utf-8')))
        except Exception as e:
            print(f"Failed to retrieve data from the URL: {e}")
            return pd.DataFrame()

# %% [markdown]
# <a class="anchor" id="part4"></a>
# # <span style="font-family: candara; font-size: 25px; font-style: normal; font-weight: bold; letter-spacing: 3px; text-align: center; color:  #01796F; line-height:1.0">4. Administrative Bounderies South African Data </span>
#
# <hr style="height: 0.5px; border: 0; background-color: #342D7E">

# %% [markdown]
# Understanding and effectively managing administrative boundaries in South African data is essential for good governance and sustainable development. Administrative boundaries delineate the jurisdictional limits of regions, provinces, municipalities, and other administrative units. These boundaries play a crucial role in resource allocation, public services, and decision-making processes. Accurate and up-to-date data on administrative boundaries is vital for efficient governance, equitable distribution of resources, and the effective delivery of public services. It also aids in urban and regional planning, disaster management, and electoral processes. Ensuring the accuracy and accessibility of administrative boundary data is integral to promoting transparency, accountability, and the achievement of South Africa's sustainability goals.

# %% [markdown]
# # <span style="font-family: candara; font-size: 15px; font-style: normal; font-weight: bold; letter-spacing: 2px; text-align: center; color:  #01796F; line-height:1.0">4.1 South African Boundary </span>

# %%
df_sa_bound = get_df(r"C:\O\Outreachy_Siziwe_2023\ZAF_AL2_South_Africa.json")

# %%
# display the dataset
df_sa_bound
# Out:
#   country ISO3166_2          name        enname       locname  \
# 0     ZAF            South Africa  South Africa  South Africa
#
#                     offname        boundary  adminlevel wikidata  \
# 0  Republic of South Africa  administrative           2     Q258
#
#          wikimedia           timestamp  \
# 0  en:South Africa 2019-10-07 22:39:02
#
#                                             geometry
# 0  MULTIPOLYGON (((37.84603 -46.85434, 37.84616 -...

# %%
df_sa_bound.shape
# Out:
# (1, 12)

# %% [markdown]
# # <span style="font-family: candara; font-size: 15px; font-style: normal; font-weight: bold; letter-spacing: 2px; text-align: center; color:  #01796F; line-height:1.0"> 4.2 South African All states Boundary </span>

# %%
df_all_states_bound = get_df(r"C:\O\Outreachy_Siziwe_2023\ZAF_ALL_states.json")

# %%
# display the dataset
df_all_states_bound.head(2)
# Out:
#   country ISO3166_2          name      enname       locname offname  \
# 0     ZAF     ZA-EC  Eastern Cape              Eastern Cape
# 1     ZAF     ZA-FS    Free State  Free State    Free State
#
#          boundary  adminlevel wikidata                 wikimedia  \
# 0  administrative           4  Q130840
# 1  administrative           4  Q160284  en:Free State (province)
#
#             timestamp                                           geometry
# 0 2019-07-15 22:01:02  MULTIPOLYGON (((29.10961 -32.04083, 29.10916 -...
# 1 2019-08-28 22:02:02  POLYGON ((24.34662 -29.65593, 24.34669 -29.655...

# %%
df_all_states_bound.shape
# Out:
# (9, 12)

# %% [markdown]
# # <span style="font-family: candara; font-size: 15px; font-style: normal; font-weight: bold; letter-spacing: 2px; text-align: center; color:  #01796F; line-height:1.0"> 4.3 South African: Gauteng Boundery </span>

# %%
df_gauteng_bound = get_df(r"C:\O\Outreachy_Siziwe_2023\ZAF_AL4_Gauteng.json")

# %%
# display the dataset
df_gauteng_bound
# Out:
#   country ISO3166_2     name enname  locname offname        boundary  \
# 0     ZAF     ZA-GT  Gauteng         Gauteng          administrative
#
#    adminlevel wikidata wikimedia           timestamp  \
# 0           4  Q133083           2019-09-09 22:03:02
#
#                                             geometry
# 0  POLYGON ((27.15634 -26.52431, 27.15876 -26.525...

# %%
df_gauteng_bound.shape
# Out:
# (1, 12)

# %% [markdown]
# <a class="anchor" id="part6"></a>
# # <span style="font-family: candara; font-size: 25px; font-style: normal; font-weight: bold; letter-spacing: 3px; text-align: center; color:  #01796F; line-height:1.0"> FOREST COVER </span>
#
# <hr style="height: 0.5px; border: 0; background-color: #342D7E">

# %% [markdown]
# The extent and management of forest cover are pivotal in South Africa's sustainability efforts. Forest cover, which includes both natural and planted forests, plays a significant role in biodiversity preservation, climate regulation, and resource supply. By conserving and responsibly managing forest cover, South Africa can protect its ecosystems, mitigate climate change, and ensure a sustainable supply of timber and non-timber products. Additionally, these forests are vital for supporting rural livelihoods, enhancing water quality, and providing recreational opportunities. Recognizing the importance of forest cover helps South Africa maintain a harmonious balance between environmental conservation and economic growth, paving the way for a more sustainable and resilient future.

# %% [markdown]
# # <span style="font-family: candara; font-size: 15px; font-style: normal; font-weight: bold; letter-spacing: 2px; text-align: center; color:  #01796F; line-height:1.0">6.1 South African: Planted forest SDPT </span>

# %% [markdown]
# Planted forests are carefully cultivated and managed to produce wood resources while minimizing ecological impact. These forests provide a sustainable source of timber and other forest products, reducing the pressure on natural ecosystems. This approach contributes to economic growth, supports local communities, and aids in achieving sustainable development goals. By promoting and responsibly managing planted forests, South Africa can foster a more sustainable and resilient future, balancing the needs of the environment and society.

# %%
df_sa_PF = get_df(r"C:\O\Outreachy_Siziwe_2023\ZAF_South Africa_SDPT.json")

# %%
# display the dataset
df_sa_PF.head(2)
# Out:
#   final_id  iso       country                    org_name common_name  \
# 0   ZAF_18  ZAF  South Africa   Cultivated orchards (low)     Unknown
# 1   ZAF_16  ZAF  South Africa  Cultivated orchards (high)     Unknown
#
#    species species_simp    plant_ag   timber_ag ever_dec conifer_broad  \
# 0  Unknown      Unknown  Tree crops  Tree crops      n/a           n/a
# 1  Unknown      Unknown  Tree crops  Tree crops      n/a           n/a
#
#   hard_soft     size                                            source  \
# 0       n/a  Unknown  South Africa Department of Environmental Affairs
# 1       n/a  Unknown  South Africa Department of Environmental Affairs
#
#         year                                           geometry
# 0  2013-2014  POLYGON ((29.65265 -22.12893, 29.65410 -22.128...
# 1  2013-2014  POLYGON ((29.65238 -22.13002, 29.65237 -22.129...

# %%
df_sa_PF.shape
# Out:
# (1165680, 16)

# %%
# Create subplot with three panels
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 10))

# Plot the hotspots by name in panel 1
df_sa_PF.plot(column="common_name", cmap="tab10", ax=ax1, legend=True)
df_sa_bio.plot(ax=ax1, color="green", edgecolor="black", alpha = 0.3)
ax1.set_title("PLANTED FORESTS IN SOUTH AFRICA BY SPECIES COMMON NAME")

# Plot the planted forests by type in panel 2
df_sa_PF.plot(column="species", cmap="tab10", ax=ax2, legend=True)
df_sa_bio.plot(ax=ax2, color="green", edgecolor="black", alpha = 0.3)
ax2.set_title("PLANTED FORESTS IN SOUTH AFRICA BY SPECIES")

# Plot the planted forests by plantation in panel 3
df_sa_PF.plot(column="plant_ag", cmap="tab10", ax=ax3, legend=True)
df_sa_bio.plot(ax=ax3, color="green", edgecolor="black", alpha = 0.3)
ax3.set_title("PLANTED FORESTS IN SOUTH AFRICA BY PLANTATION")

plt.show()

# %%
# Create subplots with the desired layout
fig, axes = plt.subplots(1, 2, figsize=(25, 20))
plt.subplots_adjust(wspace=0.1)  # Adjust the horizontal space between subplots

# South African: Hotspot by Name
ax1 = axes[0]
ax1.set_title('A Plain South African Map')
df_sa_PF.plot(ax=ax1,column="common_name", color='palegreen', edgecolor='black', alpha = 0.4) #alpha = 0.)
ax1.axis('off')

# # First subplot: South African map with biodivesity hotspot Named
ax2 = axes[0]
df_sa_bio.plot(column="NAME", cmap='tab20', ax=ax2, legend=True)
df_sa_bound.plot(ax=ax2, color="palegreen", edgecolor="black", alpha = 0.4)
ax2.set_title("South African map with biodivesity hotspot labelled")
ax2.axis('off')

# Second subplot: South African map with total area with all Biodiversity hotspots
ax3 = axes[1]
df_sa_bio.plot(column="Type", cmap='tab20', ax=ax3, legend=True)
df_sa_bound.plot(ax=ax3, color="palegreen", edgecolor="black", alpha = 0.4)
ax3.set_title("South African map : Total area with all Biodiversity hotspots")
ax3.axis('off')

plt.show()

# %% [markdown]
# <a class="anchor" id="part8"></a>
# # <span style="font-family: candara; font-size: 25px; font-style: normal; font-weight: bold; letter-spacing: 3px; text-align: center; color:  #01796F; line-height:1.0"> AGRO-ECOLOGICAL ZONES </span>
#
# <hr style="height: 0.5px; border: 0; background-color: #342D7E">

# %% [markdown]
# Understanding agro-ecological zones in South Africa is key to achieving sustainability. It enables smarter farming practices tailored to each region, conserves nature's diversity, and makes us more resilient to changing climates. By knowing our land well, we can use water wisely, reduce environmental harm, and ensure a steady food supply, all while boosting local economies and jobs. It's a practical and powerful way to move closer to a more sustainable future.

# %%
df_EZ = get_df(r"C:\O\Outreachy_Siziwe_2023\ZAF_AL2_South Africa_GEZ (1).json")

# %%
df_EZ
# Out:
#   country ISO3166_2          name                     gez_name  gez_code  \
# 0     ZAF            South Africa       Boreal tundra woodland        42
# 1     ZAF            South Africa       Subtropical dry forest        22
# 2     ZAF            South Africa     Subtropical humid forest        21
# 3     ZAF            South Africa  Subtropical mountain system        25
# 4     ZAF            South Africa              Tropical desert        15
# 5     ZAF            South Africa          Tropical dry forest        13
# 6     ZAF            South Africa        Tropical moist forest        12
# 7     ZAF            South Africa     Tropical mountain system        16
# 8     ZAF            South Africa           Tropical shrubland        14
#
#   gez_abbrev  adminlevel                                           geometry
# 0         Bb           2  MULTIPOLYGON (((37.84717 -46.85358, 37.84604 -...
# 1        SCs           2  MULTIPOLYGON (((19.33968 -34.58515, 19.33935 -...
# ...

# %%
df_EZ.shape
# Out:
# (9, 8)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(20, 10))
plt.subplots_adjust(wspace=0.1)  # Adjust the horizontal space between subplots


df_EZ.plot(ax=ax1, color="palegreen", edgecolor="black", alpha = 0.4)
df_EZ.plot(ax=ax1, column='gez_name', edgecolor='black', cmap='tab10', legend=True)
ax1.set_title("SOUTH AFRICA : AGRO-ECOLOGICAL ZONES ALL STATES (PROVINCES)")
ax1.axis('off')

plt.show()

# %% [markdown]
# <a class="anchor" id="part9"></a>
# # <span style="font-family: candara; font-size: 25px; font-style: normal; font-weight: bold; letter-spacing: 3px; text-align: center; color:  #01796F; line-height:1.0"> 9. CONLCUSION </span>
#
# <hr style="height: 0.5px; border: 0; background-color: #342D7E">

# %% [markdown]
# South Africa, a nation with unique socio-economic and environmental challenges, can harness the power of the above data analysis to address its specific sustainable development needs.
#
# South Africa, like other countries, can use this data analysis to monitor and manage its land and soil resources more effectively. Through the systematic collection, analysis, and interpretation of land and soil data, South Africa can gain insights into the health of its ecosystems, soil quality, and land use patterns. This information is instrumental in making informed decisions about land management, ensuring the sustainable use of resources, and preventing issues such as land degradation and soil erosion. By mapping soil types and their properties, the country can optimize agricultural practices, promote soil conservation, and support food security, contributing to SDG 2 (Zero Hunger) and SDG 15 (Life on Land).
#
# By using the analysis above and examining energy consumption patterns and carbon emissions data, the nation can make informed decisions on transitioning to cleaner energy sources and reducing its carbon footprint, aligning with SDG 7 (Affordable and Clean Energy) and SDG 13 (Climate Action). In urban planning, data analysis can improve public transportation systems, reduce traffic congestion, and address housing and infrastructure challenges, thus contributing to SDG 11 (Sustainable Cities and Communities). Through data-driven decision-making and monitoring, South Africa can ensure that its sustainable development efforts are evidence-based, cost-effective, and tailored to the specific needs of its diverse population.

# %% [markdown]
# <a class="anchor" id="part10"></a>
# # <span style="font-family: candara; font-size: 25px; font-style: normal; font-weight: bold; letter-spacing: 2px; text-align: center; color:  #01796F; line-height:1.0"> 10.REFERENCES </span>
#
# <hr style="height: 0.5px; border: 0; background-color: #342D7E">

# %% [markdown]
# - The Sustainable Development Goals in South Africa https://southafrica.un.org/en/sdgs
# - Department of Economic and Social Affairs Sustainable Development https://sdgs.un.org/goals
# - What is geodata used for https://www.heavy.ai/technical-glossary/geodata#:~:text=The%20application%20of%20geographic%20data,and%20repair%20of%20network%20anomalies%2C
# - GDAL documentation https://gdal.org/api/python_bindings.html
